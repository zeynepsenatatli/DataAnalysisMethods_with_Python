# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynepsenatatli/DataAnalysisMethods_with_Python/blob/main/Lab4_Test_and_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/SunspotGroupData.txt", sep="\s+")
frame = pd.DataFrame(df)
frame
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2   ua   ws    lat     lon  \
# 0      g  1976   1  12  12  11  35    675    4    9    3    5  -8.40   33.95
# 1      g  1976   1  12  12  11  35    676   10   80   15  127 -11.45  284.27
# 2      g  1976   1  14   1  13  30    675    0    5    0    4 -10.84   35.05
# 3      g  1976   1  14   1  13  30    676  128  700  106  581 -10.25  283.47
# 4      g  1976   1  15  10  22   2    675    0    1    0    3 -10.25   36.58
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ...  ...    ...     ...
# 57673  g  1996  12  22   8  10   0  8007a    0    6    0    3  -7.28  176.21
# 57674  g  1996  12  23   2  35   0   8004    9   49   16   90   5.77  251.93
# 57675  g  1996  12  23   2  35   0   8007    2   11    2   13   5.18  240.00
# 57676  g  1996  12  24  11  16  49   8008    1    5    1    3 -18.96  168.17
# 57677  g  1996  12  26   8  31  32  8008a    0    2    0    1 -22.36  148.04
#
#          lcm      pa    dcen
# ...

# %%
df = pd.read_fwf("/content/SunspotGroupData.txt", sep="\s+")
df
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2   ua   ws  lat    lon  \
# 0      g  1976   1  12  12  11  35    675  NaN    4    9    3    5  -8.40
# 1      g  1976   1  12  12  11  35    676  NaN   10   80   15  127 -11.45
# 2      g  1976   1  14   1  13  30    675  NaN    0    5    0    4 -10.84
# 3      g  1976   1  14   1  13  30    676  NaN  128  700  106  581 -10.25
# 4      g  1976   1  15  10  22   2    675  NaN    0    1    0    3 -10.25
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ...  ...  ...    ...
# 57673  g  1996  12  22   8  10   0  8007a  NaN    0    6    0    3  -7.28
# 57674  g  1996  12  23   2  35   0   8004  NaN    9   49   16   90   5.77
# 57675  g  1996  12  23   2  35   0   8007  NaN    2   11    2   13   5.18
# 57676  g  1996  12  24  11  16  49   8008  NaN    1    5    1    3 -18.96
# 57677  g  1996  12  26   8  31  32  8008a  NaN    0    2    0    1 -22.36
#
#           lcm     pa    dcen  Unnamed: 17
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = frame
X_train, X_test = train_test_split(X, test_size=0.80, random_state=42)

# %%
X_train
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2  ua   ws    lat     lon  \
# 2107   g  1978   2   3   1  15   0    996   11   71   8   50  24.21  108.41
# 30363  g  1984   6   2  15  45  42   4508    5   50  17  161   5.57  154.00
# 31262  g  1985   6   3  13  46   5   4662    9   54  37  239 -14.70    2.18
# 53596  g  1993   1  18   9  24  57   7400   18  137  30  231  -9.04  108.56
# 38216  g  1989   7  12   8  40  47   5575   18  106  16   96  24.41  143.48
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ..  ...    ...     ...
# 54343  g  1993   5  14   8  28  39   7505    1    5   2    8  12.70  233.67
# 38158  g  1989   7   7   8   1  34   5572   62  529  33  291 -19.32  168.19
# 860    g  1977   3  28  12  37  37    800    0   18   0   14  24.09  262.50
# 15795  g  1980  10  20  13  34  44  2736m    0   12   0    6  12.21   45.41
# 56422  g  1994  10  29   5   1   0   7794  127  985  73  579  13.55   78.14
#
#          lcm      pa    dcen
# ...

# %%
X_test
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2  ua   ws    lat     lon  \
# 42950  g  1990   7   8  15  28  10   6138   82  462  51  269  22.05   22.19
# 30250  g  1984   5  14  10  54   6   4483    0    1   0    2  -6.85  193.30
# 10351  g  1979  11   5   5  13  30   2093   45  178  23   91  13.49  324.48
# 22636  g  1982   2  23  13  29  17   3614   46  332  25  183 -12.73    5.84
# 34463  g  1988   8  28   7  13  13  5124m    0    3   0    2  25.70  332.57
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ..  ...    ...     ...
# 13313  g  1980   5  22  10  22   7  2466m    0    2   0    1   5.76  187.11
# 13528  g  1980   6   4   8  58  18   2481   52  304  29  170 -20.25   74.18
# 25017  g  1982   9   9  15  45  53   3889    0   18   0    8  -8.25  300.90
# 19317  g  1981   7  11  15  43  53   3202   15   26   8   13  -9.48  132.16
# 7928   g  1979   6  10  11  39  51   1799    0   11   0    6  16.28  114.81
#
#          lcm      pa    dcen
# ...

# %%
df2 = frame.replace(999999, np.nan)
df2.lat.argmin()
# Out:
# 32246

# %%
arr = pd.cut(df2.lat, 10, precision=2)
arr
# Out:
# 0          (-10.73, 0.55]
# 1        (-22.01, -10.73]
# 2        (-22.01, -10.73]
# 3          (-10.73, 0.55]
# 4          (-10.73, 0.55]
#                ...
# 57673      (-10.73, 0.55]
# 57674       (0.55, 11.84]
# 57675       (0.55, 11.84]
# 57676    (-22.01, -10.73]
# 57677    (-33.29, -22.01]
# Name: lat, Length: 57678, dtype: category
# Categories (10, interval[float64, right]): [(-55.97, -44.58] < (-44.58, -33.29] < (-33.29, -22.01] <
#                                             (-22.01, -10.73] ... (11.84, 23.12] < (23.12, 34.4] <
#                                             (34.4, 45.69] < (45.69, 56.97]]

# %%
pd.value_counts(arr)
# Out:
# (-22.01, -10.73]    14877
# (11.84, 23.12]      12967
# (0.55, 11.84]        8518
# (-10.73, 0.55]       7839
# (-33.29, -22.01]     5746
# (23.12, 34.4]        4365
# (-44.58, -33.29]      728
# (34.4, 45.69]         511
# (-55.97, -44.58]       21
# (45.69, 56.97]          3
# Name: lat, dtype: int64

# %%
df2.iloc[32246]
# Out:
# i            g
# yr        1987
# mo           5
# da          13
# hr           5
# mi          20
# se          10
# id       4807a
# pr1          0
# pr2          5
# ua         0.0
# ws         4.0
# lat     -55.86
# lon     123.74
# lcm      31.07
# pa      199.88
# dcen    0.8551
# Name: 32246, dtype: object

# %%
df2
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2     ua     ws    lat  \
# 0      g  1976   1  12  12  11  35    675    4    9    3.0    5.0  -8.40
# 1      g  1976   1  12  12  11  35    676   10   80   15.0  127.0 -11.45
# 2      g  1976   1  14   1  13  30    675    0    5    0.0    4.0 -10.84
# 3      g  1976   1  14   1  13  30    676  128  700  106.0  581.0 -10.25
# 4      g  1976   1  15  10  22   2    675    0    1    0.0    3.0 -10.25
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...    ...    ...    ...
# 57673  g  1996  12  22   8  10   0  8007a    0    6    0.0    3.0  -7.28
# 57674  g  1996  12  23   2  35   0   8004    9   49   16.0   90.0   5.77
# 57675  g  1996  12  23   2  35   0   8007    2   11    2.0   13.0   5.18
# 57676  g  1996  12  24  11  16  49   8008    1    5    1.0    3.0 -18.96
# 57677  g  1996  12  26   8  31  32  8008a    0    2    0.0    1.0 -22.36
#
#           lon    lcm      pa    dcen
# 0       33.95  36.89  261.68  0.6024
# ...

# %%
df2.lat = np.where((df2.lat < -40), -40, df2.lat)
df2.lat = np.where((df2.lat > 40), 40, df2.lat)

df2.iloc[32246]
# Out:
# i            g
# yr        1987
# mo           5
# da          13
# hr           5
# mi          20
# se          10
# id       4807a
# pr1          0
# pr2          5
# ua         0.0
# ws         4.0
# lat      -40.0
# lon     123.74
# lcm      31.07
# pa      199.88
# dcen    0.8551
# Name: 32246, dtype: object

# %%
df2.lat.max()
# Out:
# 40.0

# %%
df2
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2     ua     ws    lat  \
# 0      g  1976   1  12  12  11  35    675    4    9    3.0    5.0  -8.40
# 1      g  1976   1  12  12  11  35    676   10   80   15.0  127.0 -11.45
# 2      g  1976   1  14   1  13  30    675    0    5    0.0    4.0 -10.84
# 3      g  1976   1  14   1  13  30    676  128  700  106.0  581.0 -10.25
# 4      g  1976   1  15  10  22   2    675    0    1    0.0    3.0 -10.25
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...    ...    ...    ...
# 57673  g  1996  12  22   8  10   0  8007a    0    6    0.0    3.0  -7.28
# 57674  g  1996  12  23   2  35   0   8004    9   49   16.0   90.0   5.77
# 57675  g  1996  12  23   2  35   0   8007    2   11    2.0   13.0   5.18
# 57676  g  1996  12  24  11  16  49   8008    1    5    1.0    3.0 -18.96
# 57677  g  1996  12  26   8  31  32  8008a    0    2    0.0    1.0 -22.36
#
#           lon    lcm      pa    dcen
# 0       33.95  36.89  261.68  0.6024
# ...

# %%
test = frame.sample(frac = 0.2)
